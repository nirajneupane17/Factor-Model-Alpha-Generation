# %% [markdown]
# # 04 · Factor Regime Analysis — Bull vs Bear, Crisis Performance
# **Quant Trading Series — Project 3 of 20**
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from factor_construction import factor_decade_analysis
print("OK")

# %%
f=pd.read_csv("../data/factor_returns.csv",index_col="Date",parse_dates=True)
for nm,sd,ed in [("Dot-Com Bust","2000-03-10","2002-10-09"),
                   ("GFC","2007-10-09","2009-03-09"),
                   ("COVID Crash","2020-02-20","2020-04-30"),
                   ("Rate Shock 2022","2022-01-01","2022-12-31")]:
    crisis=f.loc[sd:ed,["MKT_RF","HML","RMW","QMJ","BAB"]].mean()*252*100
    print(f"\n{nm}:")
    print(crisis.round(1).to_string())

# %%
img=plt.imread("../results/05_regime_analysis.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()
